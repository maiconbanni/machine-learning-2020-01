# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import plotly.express as px

# %%
dataset_enem = pd.read_csv("dataset_20200529.csv", sep=",", encoding='ISO-8859-1')

# %%
dataset_enem.columns
# Out:
# Index(['UF_RESIDENCIA', 'FAIXA_ETARIA', 'SEXO', 'ESTADO_CIVIL', 'COR_RACA',
#        'ENSINO_CONCLUIDO', 'IDIOMA', 'ENSINO_RELULAR', 'ESCOLARIDADE_DOS_PAIS',
#        'FAIXA_RENDA_PERCAPTA', 'RENDA_PERCAPTA', 'TEM_INTERNET',
#        'RECEM_FORMADO', 'ENSINO_PUBLICO', 'NOTA_CN', 'NOTA_CH', 'NOTA_LC',
#        'NOTA_MT', 'NOTA_REDACAO', 'MEDIA_GERAL', 'RENDIMENTO_GERAL'],
#       dtype='object')

# %%
dataset_enem.UF_RESIDENCIA.value_counts()
# Out:
# SP    521769
# MG    344234
# BA    236537
# RJ    218511
# CE    183032
# PE    173045
# PA    172203
# MA    134155
# RS    133391
# PR    132234
# GO    100130
# PB     93649
# RN     76305
# PI     74368
# SC     67371
# ES     66256
# AM     65984
# DF     61677
# AL     55902
# MT     48915
# SE     44103
# MS     37302
# RO     33950
# TO     29981
# AC     22607
# AP     22366
# RR      7297
# Name: UF_RESIDENCIA, dtype: int64

# %%
dataset_enem.columns
# Out:
# Index(['UF_RESIDENCIA', 'FAIXA_ETARIA', 'SEXO', 'ESTADO_CIVIL', 'COR_RACA',
#        'ENSINO_CONCLUIDO', 'IDIOMA', 'ENSINO_RELULAR', 'ESCOLARIDADE_DOS_PAIS',
#        'FAIXA_RENDA_PERCAPTA', 'RENDA_PERCAPTA', 'TEM_INTERNET',
#        'RECEM_FORMADO', 'ENSINO_PUBLICO', 'NOTA_CN', 'NOTA_CH', 'NOTA_LC',
#        'NOTA_MT', 'NOTA_REDACAO', 'MEDIA_GERAL', 'RENDIMENTO_GERAL'],
#       dtype='object')

# %%
#MAPA DE CALOR DA MÉDIA GERAL DOS ALUNOS POR ESTADO E RENDA PERCAPTA EM FORMA DE "MAPA"

# %%
mapa = folium.Map([-9.704139, -51.189095], zoom_start=4)

arquivo_json = 'Brasil.json'

folium.Choropleth(
    geo_data=arquivo_json,
    data=dataset_enem,
    columns=['UF_RESIDENCIA', 'MEDIA_GERAL'],
    key_on='feature.properties.UF',
    fill_color='YlGn',
    #bins=6
    #bins=[300, 400, 500, 600, 700, 800]
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
py.iplot(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-97f27794210c> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 sns.boxplot(x='FAIXA_RENDA_PERCAPTA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='REGIAO')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2239     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2240                           orient, color, palette, saturation,
# -> 2241                           width, dodge, fliersize, linewidth)
#    2242
#    2243     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
# ...

# %%
mpc1 = dataset_enem.pivot_table(values='UF_RESIDENCIA', index='UF_RESIDENCIA', columns='FAIXA_RENDA_PERCAPTA')
plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='YlGn', linecolor='gray', linewidths=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-55304d3b1c72> in <module>
# ----> 1 mpc1 = dataset_enem.pivot_table(values='UF_RESIDENCIA', index='UF_RESIDENCIA', columns='FAIXA_RENDA_PERCAPTA')
#       2 plt.figure(figsize=(15,8))
#       3 sns.heatmap(mpc1, cmap='YlGn', linecolor='gray', linewidths=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6078             dropna=dropna,
#    6079             margins_name=margins_name,
# -> 6080             observed=observed,
#    6081         )
#    6082
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      98         values = list(values)
#      99
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='YlGn', linecolor='gray', linewidths=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='YlGnBu', linecolor='gray', linewidths=1)

# %%
#MAPA DE CALOR DA NOTA_CN DOS ALUNOS POR ESTADO E SEXO.

# %%
mapa = folium.Map([-9.704139, -51.189095], zoom_start=4)

arquivo_json = 'Brasil.json'

folium.Choropleth(
    geo_data=arquivo_json,
    data=dataset_enem,
    columns=['UF_RESIDENCIA', 'NOTA_CN'],
    key_on='feature.properties.UF',
    fill_color='Blues',
    #bins=6
    bins=[350, 450, 550, 650, 750]
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mpc1 = dataset_enem.pivot_table(values='NOTA_CN', index='UF_RESIDENCIA', columns='SEXO')

# %%
plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='Blues', linecolor='gray', linewidths=1)

# %%
#MAPA DE CALOR DA NOTA_CH DOS ALUNOS POR ESTADO E SEXO.

# %%
mapa = folium.Map([-9.704139, -51.189095], zoom_start=4)

arquivo_json = 'Brasil.json'

folium.Choropleth(
    geo_data=arquivo_json,
    data=dataset_enem,
    columns=['UF_RESIDENCIA', 'NOTA_CH'],
    key_on='feature.properties.UF',
    fill_color='Greens',
    #bins=6
    bins=[350, 450, 550, 650, 750]
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mpc1 = dataset_enem.pivot_table(values='NOTA_CH', index='UF_RESIDENCIA', columns='SEXO')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='Greens', linecolor='gray', linewidths=1)

# %%
#MAPA DE CALOR DA NOTA_LC DOS ALUNOS POR ESTADO E SEXO.

# %%
mapa = folium.Map([-9.704139, -51.189095], zoom_start=4)

arquivo_json = 'Brasil.json'

folium.Choropleth(
    geo_data=arquivo_json,
    data=dataset_enem,
    columns=['UF_RESIDENCIA', 'NOTA_LC'],
    key_on='feature.properties.UF',
    fill_color='YlOrBr',
    #bins=6
    bins=[250, 350, 450, 550, 650, 750, 850]
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataset_enem.SEXO.value_counts()
# Out:
# 1    1857730
# 0    1299544
# Name: SEXO, dtype: int64

# %%
mpc1 = dataset_enem.pivot_table(values='NOTA_LC', index='UF_RESIDENCIA', columns='SEXO')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='YlOrBr', linecolor='gray', linewidths=1)

# %%
#MAPA DE CALOR DA NOTA_MT DOS ALUNOS POR ESTADO E SEXO.

# %%
mapa = folium.Map([-9.704139, -51.189095], zoom_start=4)

arquivo_json = 'Brasil.json'

folium.Choropleth(
    geo_data=arquivo_json,
    data=dataset_enem,
    columns=['UF_RESIDENCIA', 'NOTA_MT'],
    key_on='feature.properties.UF',
    fill_color='PuRd',
    #bins=6
    bins=[250, 350, 450, 550, 650, 750, 850]
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mpc1 = dataset_enem.pivot_table(values='NOTA_MT', index='UF_RESIDENCIA', columns='SEXO')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='Blues', linecolor='gray', linewidths=1)

# %%
#MAPA DE CALOR DA NOTA_REDACAO DOS ALUNOS POR ESTADO E SEXO.

# %%
mapa = folium.Map([-9.704139, -51.189095], zoom_start=4)

arquivo_json = 'Brasil.json'

folium.Choropleth(
    geo_data=arquivo_json,
    data=dataset_enem,
    columns=['UF_RESIDENCIA', 'NOTA_REDACAO'],
    key_on='feature.properties.UF',
    fill_color='Greys',
    #bins=6
    bins=[250, 350, 450, 550, 650, 750, 850]
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mpc1 = dataset_enem.pivot_table(values='NOTA_REDACAO', index='UF_RESIDENCIA', columns='SEXO')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='PuRd', linecolor='gray', linewidths=1)
plt.savefig("teste.png")

# %%
mpc1 = dataset_enem.pivot_table(values='COR_RACA', index='UF_RESIDENCIA', columns='ENSINO_PUBLICO')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='Blues', linecolor='gray', linewidths=1)
plt.savefig('raca_uf_ensino_publico.png')

# %%
mpc1 = dataset_enem.pivot_table(values='RENDA_PERCAPTA', index='ESCOLARIDADE_DOS_PAIS', columns='COR_RACA')

plt.figure(figsize=(8,4))
sns.heatmap(mpc1, cmap='hot', linecolor='gray', linewidths=1)

# %%
# MAPA DE DISTRIBUIÇÃO DA MÉDIA GERAL POR LINGUA (JÁ FOI FEITO)

# %%
mpc1 = dataset_enem.pivot_table(values='MEDIA_GERAL', index='UF_RESIDENCIA', columns='IDIOMA')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='inferno', linecolor='gray', linewidths=1)

# %%
# MAPA DE DISTRIBUIÇÃO DA MÉDIA GERAL PELA ESCOLARIDADE DOS PAIS (JÁ FOI FEITO, MAS PRECISA CONTEMPLAR A NOVA CATEGORIA)

# %%
mpc1 = dataset_enem.pivot_table(values='MEDIA_GERAL', index='UF_RESIDENCIA', columns='ESCOLARIDADE_DOS_PAIS')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='plasma_r', linecolor='gray', linewidths=1)

# %%
#MAPA DE DISTRIBUIÇÃO DA COR_RACA POR ESTADO EM FORMA DE "MAPA".

# %%
dataset_enem.COR_RACA.value_counts()
# Out:
# 1    1923441
# 0    1215488
# 2      18345
# Name: COR_RACA, dtype: int64

# %%
mapa = folium.Map([-9.704139, -51.189095], zoom_start=4)

arquivo_json = 'Brasil.json'

folium.Choropleth(
    geo_data=arquivo_json,
    data=dataset_enem,
    columns=['UF_RESIDENCIA', 'COR_RACA'],
    key_on='feature.properties.UF',
    fill_color='Greys',
    #bins=6
    bins=[0, 1, 2, 3]
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CARACTERISTICAS PREDOMINANTES NOS ALUNOS COM MÉDIA GERAL IGUAL A EXCELENTE.

# %%
dataset_enem.Q027[(dataset_enem.Q027 =='A') | (dataset_enem.Q027 =='B') | (dataset_enem.Q027 =='C')] = 1

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
#CARACTERISTICAS PREDOMINANTES NOS ALUNOS COM MÉDIA GERAL IGUAL A INSUFICIENTE.

# %%
#MAPA DE CALOR DA COR_RACA POR ESTADO/REGIAO E RENDA PERCAPTA.

# %%
mpc1 = dataset_enem.pivot_table(values='RENDA_PERCAPTA', index='UF_RESIDENCIA', columns='COR_RACA')

plt.figure(figsize=(15,8))
sns.heatmap(mpc1, cmap='hot', linecolor='gray', linewidths=1)

# %%
dataset_enem.REGIAO[(dataset_enem.REGIAO !='NORTE')] = np.NaN
dataset_enem.dropna(axis=0, inplace=True)
plt.figure(figsize=(25,10))
sns.boxplot(x='UF_RESIDENCIA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='FAIXA_RENDA_PERCAPTA')
# Out:
# C:\Users\Vinicius\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_enem.REGIAO[(dataset_enem.REGIAO !='NORDESTE')] = np.NaN
dataset_enem.dropna(axis=0, inplace=True)
plt.figure(figsize=(25,10))
sns.boxplot(x='UF_RESIDENCIA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='FAIXA_RENDA_PERCAPTA')
# Out:
# C:\Users\Vinicius\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_enem.REGIAO[(dataset_enem.REGIAO !='CENTRO-OESTE')] = np.NaN
dataset_enem.dropna(axis=0, inplace=True)
plt.figure(figsize=(25,10))
sns.boxplot(x='UF_RESIDENCIA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='FAIXA_RENDA_PERCAPTA')
# Out:
# C:\Users\Vinicius\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_enem.REGIAO[(dataset_enem.REGIAO !='SUDESTE')] = np.NaN
dataset_enem.dropna(axis=0, inplace=True)
plt.figure(figsize=(25,10))
sns.boxplot(x='UF_RESIDENCIA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='FAIXA_RENDA_PERCAPTA')
# Out:
# C:\Users\Vinicius\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_enem.REGIAO[(dataset_enem.REGIAO !='SUL')] = np.NaN
dataset_enem.dropna(axis=0, inplace=True)
plt.figure(figsize=(25,10))
sns.boxplot(x='UF_RESIDENCIA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='FAIXA_RENDA_PERCAPTA')
# Out:
# C:\Users\Vinicius\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='UF_RESIDENCIA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='FAIXA_RENDA_PERCAPTA')

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='FAIXA_RENDA_PERCAPTA', y='MEDIA_GERAL', data=dataset_enem, palette='rainbow', hue='REGIAO')

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='REGIAO', y='MEDIA_GERAL', data=dataset_enem, palette='viridis', hue='FAIXA_RENDA_PERCAPTA')

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='REGIAO', y='MEDIA_GERAL', data=dataset_enem, palette='inferno', hue='ESCOLARIDADE_DOS_PAIS')

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='ESCOLARIDADE_DOS_PAIS', y='MEDIA_GERAL', data=dataset_enem, palette='magma', hue='REGIAO')

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x='REGIAO', y='MEDIA_GERAL', data=dataset_enem, hue='IDIOMA', split=True, palette='winter')

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x='REGIAO', y='MEDIA_GERAL', data=dataset_enem, hue='SEXO', split=True, palette='magma')

# %%
dataset_enem.columns
# Out:
# Index(['UF_RESIDENCIA', 'FAIXA_ETARIA', 'SEXO', 'ESTADO_CIVIL', 'COR_RACA',
#        'ENSINO_CONCLUIDO', 'IDIOMA', 'ENSINO_RELULAR', 'ESCOLARIDADE_DOS_PAIS',
#        'FAIXA_RENDA_PERCAPTA', 'RENDA_PERCAPTA', 'TEM_INTERNET',
#        'RECEM_FORMADO', 'ENSINO_PUBLICO', 'NOTA_CN', 'NOTA_CH', 'NOTA_LC',
#        'NOTA_MT', 'NOTA_REDACAO', 'MEDIA_GERAL', 'RENDIMENTO_GERAL'],
#       dtype='object')

# %%
data = dataset_enem.pivot_table(values='NOTA_CN', index='UF_RESIDENCIA', columns='SEXO')
plt.figure(figsize=(15,7))
